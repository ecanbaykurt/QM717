# %% [markdown]
# # 🏌️‍♂️ Golf & CEO Performance: Python + Statistics Starter Notebook
# Welcome!
# This is your second Python and statistics exercise.
# We will explore how a CEO’s golf handicap might be related to their company’s performance, using real Excel data, simple Python, and easy statistics.

# %% [markdown]
# # Step 1: Import Libraries

# %% [markdown]
# pandas helps us read and analyze table data.
# numpy helps us do mathematical calculations.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Step 2: Mount Your Google Drive

# %% [markdown]
# To access your Excel file, we need to connect to your Google Drive.
#
# Explanation:
#
# Google Colab is an online tool, and your file is on your Google Drive. This step allows Colab to find and use your file.

# %%
# Mount Your Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Step 3: Set the File Path

# %% [markdown]
# Update the path to match where your file is saved in Google Drive.
#
# Tip:
#
# Use the left folder icon in Colab to browse your Drive and find the correct path if needed.

# %%
# Change between ' ' with your file path
file_path = '/content/drive/MyDrive/QM717-2025/In-Class Excel and Python Exercises/Second Week/Golf 1.xlsx'

# %% [markdown]
# #Step 4: Load the Data Using Pandas

# %% [markdown]
# Let’s read the Excel file into a Pandas DataFrame — think of this like importing a table into Python.
#
# .head() shows the first 5 rows of your data. This helps you make sure the file was loaded correctly.

# %%
df = pd.read_excel(file_path)
df.head()
# Out:
#     Last Name   First Name             Company  Performance  Handicap
# 0       Bijur     Peter I.              Texaco           35      27.1
# 1  Bonsignore      Michael           Honeywell           38      22.0
# 2     Bossidy  Lawrence A.       Allied Signal           51      12.6
# 3      Bowlin      Mike R.  Atlantic Richfield           35      16.6
# 4     Buffett    Warren E.  Berkshire Hathaway           43      22.0

# %% [markdown]
# #Step 5: Visualize the Dataset

# %% [markdown]
# In this step, we will create our first graphs using matplotlib.
#
# - Visualization helps us understand data patterns, trends, and relationships without reading large tables.
# - We need to import our visualizor tool in python which is matplotlib

# %%
import matplotlib.pyplot as plt  # matplotlib is a library to make plots in Python

# %% [markdown]
# We are plotting each company as a point on a graph, where the x-position shows their golf handicap and the y-position shows how well the company performs. Then we label the axes and give the plot a title so it’s clear what the viewer is looking at.

# %% [markdown]
# What this code does:
#
# - plt.scatter(df['Handicap'], df['Performance']) ---> This line draws the dots on the graph.
#
#   - X‑axis → df['Handicap'] (the golf handicap values for each company)
#
#   - Y‑axis → df['Performance'] (the corporate performance values)
#
# - plt.xlabel('Golf Handicap') ---> Labeling axes is important because without labels, the viewer will not understand the chart.
#
#
# - plt.ylabel('Corporate Performance') ---> This names the y‑axis so we know what the vertical numbers mean.
#
#
# - plt.title('Golf vs Corporate Performance') -- > Adds a title at the top of the graph. A good title summarizes the story the graph is trying to tell.
#
#
# - plt.show() --> This actually displays the plot in the notebook. Without show(), the graph might not appear.
#
# Think of it as saying, “Okay, Python, please show my picture now!”

# %%
# Assuming your DataFrame is df
# Scatter plot: Golf Handicap vs Corporate Performance
plt.scatter(df['Handicap'], df['Performance'])

# Add labels and title
plt.xlabel('Golf Handicap')
plt.ylabel('Corporate Performance')
plt.title('Golf vs Corporate Performance')

plt.show()

# %% [markdown]
# This scatter plot shows the relationship between a company’s golf handicap and its corporate performance. Each dot on the graph represents a single company. The x-axis measures golf handicap, where lower numbers mean better golf skill, and the y-axis measures the company’s performance. By plotting the data this way, we can visually explore whether there is a pattern: for example, do CEOs with lower golf handicaps tend to lead companies with higher performance? Visualizations like this help us quickly identify trends, outliers, and relationships in the data that are harder to see in a raw table of numbers.

# %% [markdown]
# Step by step, how can wee add name for each data point on the scatter plot.
#
# for i, txt in enumerate(df['Company']):
#
# This goes through the list of company names one by one.
#
# i is the number of the row (0, 1, 2, …).
#
# txt is the company name (like "Apple" or "Google").
#
# plt.annotate(txt, (df['Handicap'][i], df['Performance'][i]))
#
# annotate means write text on the graph.
#
# txt is the name we want to write.
#
# (df['Handicap'][i], df['Performance'][i]) is the location of the dot for that company.
#
# fontsize=8 makes the name small.
#
# alpha=0.7 makes the name a bit transparent so it doesn’t clutter the chart.

# %%
# Assuming your DataFrame is df
# Scatter plot: Golf Handicap vs Corporate Performance
plt.figure(figsize=(8, 5))
plt.scatter(df['Handicap'], df['Performance'], color='green')

# Add labels and title
plt.xlabel('Golf Handicap (Lower is Better)')
plt.ylabel('Corporate Performance')
plt.title('Golf Handicap vs Corporate Performance')

# Optional: show company names next to points
for i, txt in enumerate(df['Company']):
    plt.annotate(txt, (df['Handicap'][i], df['Performance'][i]), fontsize=8, alpha=0.7)

plt.grid(True)
plt.show()

# %% [markdown]
# ## Do It Yourself

# %%
##DIY
#       - The color ('red', 'purple', 'orange', etc.)
#       - The marker style: marker='x', marker='s' (square), marker='*'
#       - The title to something fun like "Do Golfers Make Better CEOs?"
# Fill the *** on below with correct fuction.

# %%
# Assuming your DataFrame is df
# Scatter plot: Golf Handicap vs Corporate Performance
plt.figure(figsize=(8, 5))
plt.scatter(df['Handicap'], df['Performance'], color=***, marker=***)

# Add labels and title
plt.xlabel('Golf Handicap (Lower is Better)')
plt.ylabel('Corporate Performance')
plt.title(***)

# Optional: show company names next to points
for i, txt in enumerate(df['Company']):
    plt.annotate(txt, (df['Handicap'][i], df['Performance'][i]), fontsize=8, alpha=0.7)

plt.grid(True)
plt.show()
